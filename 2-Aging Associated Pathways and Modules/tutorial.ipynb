# %%
from B01_FeatureImportanceRanking import AgeAcc, AgeAccPerGO
import pandas as pd 


cofunder = "../Demo Meta Data/covariateData.pickle"
cofunder = pd.read_pickle(cofunder)

predictionResult = "../Demo Results/DemoTesting_Prediction.csv"
predictionResult = pd.read_csv(predictionResult, index_col=0)
AgeAcc_df = AgeAcc(predictionResult, cofunder)
AgeAcc_df
# Out:
#                Full      Tag
# GSM989827 -0.247193  Control
# GSM989828 -0.090885  Control
# GSM989829  0.253131  Control
# GSM989830 -0.069136  Control
# GSM989831  0.007039  Control
# GSM989832  0.092999  Control
# GSM989833  0.189109  Control
# GSM989834  0.031242  Control
# GSM989835 -0.245463  Control
# GSM989836  0.065841  Control
# GSM989837 -0.336006  Control
# GSM989838  0.103026  Control
# GSM989839  0.317701  Control
# GSM989840 -0.066018  Control
# GSM989841 -0.110756  Control
# GSM989842 -0.161075  Control
# GSM989843 -0.005343  Control
# GSM989844  0.054261  Control
# GSM989845  0.129114  Control
# GSM989846 -0.025791  Control
# GSM989847 -0.008914  Control
# GSM989848  0.280702  Control
# GSM989849 -0.124674  Control
# GSM989850  0.160846  Control
# GSM989851 -0.193755  Control

# %%
data4Stage2 = '../Demo Results/DemoTestingData4Stage2.csv'
data4Stage2 = pd.read_csv(data4Stage2, index_col=0)   
data4Stage2 = data4Stage2.drop(columns= ["Age"]) 

import sys
sys.path.append('../1-PahtwayAge Model/')
from A03supp_age import antiAgeTransfer

data4Stage2 = data4Stage2.applymap(lambda x: antiAgeTransfer(x))

AgeAccPerGO_df = AgeAccPerGO(data4Stage2, cofunder)
AgeAccPerGO_df
# Out:
# /tmp/ipykernel_2244639/661503360.py:9: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   data4Stage2 = data4Stage2.applymap(lambda x: antiAgeTransfer(x))
#            GO:0007264  GO:0006412  GO:0000209  GO:0007411  GO:0007605  \
# GSM989827   -0.012945   -0.076566   -0.002902    1.357329   -0.549139
# GSM989828   -0.014005   -0.114390    0.000671    0.174949   -0.298689
# GSM989829    0.005760    0.225129    0.000510   -1.003739    0.241125
# GSM989830   -0.038997   -0.004352   -0.001561    0.214440   -0.968520
# GSM989831    0.015683   -0.041316    0.003288   -0.141284    0.512870
# GSM989832   -0.004971    0.046067   -0.000099   -0.496726   -0.069400
# GSM989833   -0.000735    0.042988   -0.001997   -1.021429   -0.004584
# GSM989834    0.013591    0.212334   -0.002867    0.501617    0.122308
# GSM989835    0.013605   -0.347386    0.003188    0.670532    0.395249
# GSM989836    0.008776   -0.041496    0.000020   -0.457528    0.245894
# ...
