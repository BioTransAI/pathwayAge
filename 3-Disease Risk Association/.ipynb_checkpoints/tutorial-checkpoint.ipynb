# %%
from C01_AgeAcclerationInCase import testAgeAccInCase
import pandas as pd 

#Test if ageacc there is a significant difference between case and control groups

testAgeAccInCase()
# Out:
#         PathwayAge(GO)  PathwayAge(KEGG)  DNAmAge  DNAmAgeHannum  \
# P                0.000             0.000    0.000          0.000
# Differ           0.986             0.986    0.673          0.644
#
#         DNAmPhenoAge  DNAmGrimAgeBasedOnRealAge  Epigenetic Age (Zhang)  \
# P              0.000                       0.00                   0.000
# Differ         1.388                       0.52                   0.791
#
#             Data
# P       gse40279
# Differ  gse40279
