# %%
# to test pathwayAge
from A06pathwayAge import pathwayAge
import pandas as pd 
# methylData and resultName are positional arguments
# methylData: pd.DataFrame,
# resultName: str,
resultName = "Demo"

methylDataAge = "../Demo Meta Data/methlyData.pickle"
covariateData =  "../Demo Meta Data/covariateData.pickle"
methylDataAge = pd.read_pickle(methylDataAge)
covariateData = pd.read_pickle(covariateData)
age = covariateData[["Age"]]
methylDataAge.head()
# Out:
#            cg00000029  cg00000108  cg00000109  cg00000165  cg00000236  \
# GSM989827    0.464197    0.941091    0.911182    0.132014    0.717861
# GSM989828    0.454883    0.939033    0.596455    0.206917    0.723935
# GSM989829    0.485764    0.918802    0.870333    0.162861    0.719196
# GSM989830    0.480785    0.929908    0.889689    0.197780    0.704061
# GSM989831    0.501220    0.934548    0.890450    0.148437    0.754913
#
#            cg00000289  cg00000292  cg00000321  cg00000363  cg00000622  ...  \
# GSM989827    0.686521    0.805003    0.228244    0.338483    0.016508  ...
# GSM989828    0.619084    0.814672    0.310879    0.418998    0.005747  ...
# GSM989829    0.635678    0.824336    0.263215    0.424736    0.012197  ...
# GSM989830    0.610864    0.811152    0.316761    0.398772    0.019945  ...
# GSM989831    0.651262    0.808628    0.338289    0.366965    0.000000  ...
#
#            cg00484358  cg00484396  cg00484466  cg00484484  cg00484488  \
# ...

# %%
covariateData.head()
# Out:
#            Female   Age   CD8.naive  CD8pCD28nCD45RAn  PlasmaBlast      CD4T  \
# GSM989827     1.0  67.0  243.108097          6.189957     1.715995  0.208047
# GSM989828     1.0  89.0  209.846119         16.772700     2.080501  0.078482
# GSM989829     1.0  66.0  221.816625         10.683880     1.905257  0.139819
# GSM989830     1.0  64.0  174.033597         12.431503     2.079836  0.081060
# GSM989831     1.0  62.0  233.514182         11.196749     1.673152  0.173364
#
#                  NK      Mono      Gran  population_0  ...  population_4  \
# GSM989827  0.000000  0.054644  0.704654    -10.044272  ...     -0.965633
# GSM989828  0.016253  0.086040  0.802670    -19.428282  ...     -1.502283
# GSM989829  0.000000  0.049906  0.719911     -7.224595  ...     -3.208919
# GSM989830  0.037106  0.076204  0.740136    -11.317761  ...     -4.495296
# GSM989831  0.062574  0.045892  0.673273     -5.820372  ...     -3.723189
#
# ...

# %%
# the rest are optional arguments
# pathwayType: Optional[str] = "GO",
# methylTestData: Optional[pd.DataFrame] = pd.DataFrame(),
# restrictUp: Optional[int] = 200,
# restrictDown: Optional[int] = 10,
# minPathSize: Optional[int] = 5,
# nfold: Optional[int] = 5,
# randomState: Optional[int] = 6677,
# predictionMode: Optional[str] = "GradientBoosting",
# reconData: Optional[boolean] = False,
# tuneHyperParam: Optional[boolean] = False,
# hyperParam: Optional[dict]= None,
# cores: Optional[int]= 5,

methylTrainData = methylDataAge.iloc[25:50, :1000].join(age)
methylTestData = methylDataAge.iloc[:25, :1000].join(age)
restrictUp = 20
restrictDown = 10
minPathSize = 10
nfold = 6
randomState = 00
predictionMode = "Ridge"
tuneHyperParam = True
hyperParam = {'alphas': [0.01, 0.1, 1, 10]}
cores = 10

### GB example ###
# hyperParam = {
#     "n_estimators": 50,
#     "max_depth": 4,
#     "min_samples_split": 5,
#     "learning_rate": 0.01,
#     "loss": "squared_error",
# }
### SVM example ###
# hyperParam = {
#     "kernel": ["rbf", "poly"],
#     "C": [20, 10, 1, 0.1],
#     "epsilon": [0.001, 0.01, 0.1, 1]
#         }

# %%
pathwayAge(
    methylData = methylTrainData,
    resultName = resultName,
    minPathSize = 10,
    nfold = nfold,
    tuneHyperParam  = tuneHyperParam,
    hyperParam = hyperParam,
    cores= cores,
    pathwayType = "GO",
    methylTestData = methylTestData,
    predictionMode = predictionMode,
)
print("Done")
# Out:
# (25, 22)
# all labels are used for training without cross-validation!
# (25, 22)
# data4Stage2 testing dataset!
# prediction            prediction       Age
# GSM989827    2.633916  2.238095
# GSM989828    2.591456  3.285714
# GSM989829    2.612167  2.190476
# GSM989830    2.603418  2.095238
# GSM989831    2.668243  2.000000
# GSM989832    2.637852  3.190476
# GSM989833    2.660157  2.523810
# GSM989834    2.647631  2.619048
# GSM989835    2.658613  2.523810
# GSM989836    2.653041  3.000000
# GSM989837    2.545022  2.952381
# GSM989838    2.585457  1.333333
# GSM989839    2.756203  2.714286
# GSM989840    2.663893  1.619048
# GSM989841    2.646412  2.047619
# GSM989842    2.639650  2.428571
# GSM989843    2.629264  2.285714
# GSM989844    2.627266  2.857143
# GSM989845    2.624700  3.428571
# GSM989846    2.683301  1.904762
# GSM989847    2.662871  2.809524
# GSM989848    2.613724  2.285714
# GSM989849    2.629768  3.476190
# GSM989850    2.609483  3.047619
# ...

# %%
def linearRegressionScore(X, y):
    # using linear regression score function to compute the r2
    from sklearn.linear_model import LinearRegression
    model = LinearRegression()
    model.fit(X, y)
    r_squared = model.score(X, y)
    return r_squared
    
def evaluation(predictionAge):
    from sklearn.metrics import mean_absolute_error, mean_squared_error
    mean_squared_error = mean_squared_error(predictionAge["Age"].values, predictionAge["prediction"].values)
    mean_absolute_error = mean_absolute_error(predictionAge["Age"].values, predictionAge["prediction"].values)
    r2_score = linearRegressionScore(predictionAge[["Age"]], predictionAge[["prediction"]])
    dataCorr = predictionAge.drop(columns=["Age"]).corrwith(predictionAge['Age'], method='pearson')
    return mean_squared_error, mean_absolute_error, r2_score, dataCorr.values[0]


prediction = pd.read_csv("../Demo Results/DemoTesting_Prediction.csv", index_col = 0)
mean_squared_error, mean_absolute_error, r2_score, dataCorr = evaluation(prediction) 

print(f"Mean Squared Error (MSE): {mean_squared_error:.4f}")
print(f"Mean Absolute Error (MAE): {mean_absolute_error:.4f}")
print(f"R^2 Score: {r2_score:.4f}")
print(f"Pearson Correlation: {dataCorr:.4f}")
# Out:
# Mean Squared Error (MSE): 128.5358
# Mean Absolute Error (MAE): 9.8456
# R^2 Score: 0.0576
# Pearson Correlation: 0.2399
