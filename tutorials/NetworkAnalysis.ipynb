# %%
import numpy as np
import pandas as pd 
from functools import reduce
import json
from flask import Flask, render_template

# step0 import data
root = "./analysis/discovery3KGOClusterSub/{}"
clusterRandIndexPath = root.format("moduleRandIndex.csv")
GOAncestorPath = "./analysis/GO_Ancestor.csv"
clusterRandIndex = pd.read_csv(clusterRandIndexPath,  index_col=0)
GOAncestor = pd.read_csv(GOAncestorPath)
clusterRandIndex
# Out:
#     cutHeight  minClusterSize  randIndex
# 1       0.990              10   0.012770
# 2       0.990              20   0.012770
# 3       0.990              30   0.012770
# 4       0.991              10   0.012770
# 5       0.991              20   0.012770
# 6       0.991              30   0.012770
# 7       0.992              10   0.012770
# 8       0.992              20   0.012770
# 9       0.992              30   0.012770
# 10      0.993              10   0.012770
# 11      0.993              20   0.012770
# 12      0.993              30   0.012770
# 13      0.994              10   0.012770
# 14      0.994              20   0.012770
# 15      0.994              30   0.012770
# 16      0.995              10   0.062974
# 17      0.995              20   0.012770
# 18      0.995              30   0.012770
# 19      0.996              10   0.088377
# 20      0.996              20   0.012770
# 21      0.996              30   0.012770
# 22      0.997              10   0.102661
# 23      0.997              20   0.012770
# 24      0.997              30   0.012770
# 25      0.998              10   0.243279
# 26      0.998              20   0.012770
# 27      0.998              30   0.012770
# 28      0.999              10   0.495022
# 29      0.999              20   0.012770
# 30      0.999              30   0.012770

# %%
GOAncestor
# Out:
#                 GO                              Name  \
# 0       GO:0000001         mitochondrion inheritance
# 1       GO:0000001         mitochondrion inheritance
# 2       GO:0000002  mitochondrial genome maintenance
# 3       GO:0000011               vacuole inheritance
# 4       GO:0000012        single strand break repair
# ...            ...                               ...
# 158445  GO:2001316      kojic acid metabolic process
# 158446  GO:2001317   kojic acid biosynthetic process
# 158447  GO:2001317   kojic acid biosynthetic process
# 158448  GO:2001317   kojic acid biosynthetic process
# 158449  GO:2001317   kojic acid biosynthetic process
#
#                                              Ancestor  AncestorGO
# 0                               cellular localization  GO:0051641
# 1       cellular component organization or biogenesis  GO:0071840
# 2       cellular component organization or biogenesis  GO:0071840
# 3       cellular component organization or biogenesis  GO:0071840
# 4                 nitrogen compound metabolic process  GO:0006807
# ...                                               ...         ...
# 158445            organic substance metabolic process  GO:0071704
# 158446                           biosynthetic process  GO:0009058
# 158447                     cellular metabolic process  GO:0044237
# 158448               small molecule metabolic process  GO:0044281
# 158449            organic substance metabolic process  GO:0071704
#
# [158450 rows x 4 columns]

# %%
# step1 find the cutHeight and minCluster size
selectedParameter = clusterRandIndex.nlargest(1, "randIndex")
cutHeight = selectedParameter["cutHeight"].values[0]
minClusterSize = selectedParameter["minClusterSize"].values[0]
print(cutHeight, minClusterSize)
# Out:
# 0.999 10

# %%
# step2 Cluster with fixed cutHeight and minCluster size 
ClusterWithFixedParaPath = root.format("_trueModuleCluster_" + str(cutHeight) + "_" + str(minClusterSize) + "_.csv")
cluster = pd.read_csv(ClusterWithFixedParaPath, index_col=0).rename(columns={"Label": "Cluster"})
cluster.GO = cluster.GO.str.replace(".", ":")
cluster
# Out:
# /tmp/ipykernel_344142/2302645368.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   cluster.GO = cluster.GO.str.replace(".", ":")
#              GO                                      AncestorGroup  \
# 1    GO:0000002      cellular component organization or biogenesis
# 2    GO:0000012  nitrogen compound metabolic process,cellular m...
# 3    GO:0000027      cellular component organization or biogenesis
# 4    GO:0000028      cellular component organization or biogenesis
# 5    GO:0000038  cellular metabolic process,primary metabolic p...
# ..          ...                                                ...
# 496  GO:0007018  movement of cell or subcellular component,micr...
# 497  GO:0007019  microtubule-based process,cellular component o...
# 498  GO:0007020  microtubule-based process,cellular component o...
# 499  GO:0007026  microtubule-based process,negative regulation ...
# 500  GO:0007029      cellular component organization or biogenesis
#
#      AncestorGroupIndex  Color  Cluster
# 1                  1344    239        1
# 2                  3194    596        0
# 3                  1344    239        1
# 4                  1344    239        0
# 5                  1564    314        1
# ..                  ...    ...      ...
# 496                2343    450        1
# 497                2149    421        0
# 498                2149    421        1
# 499                2154    422        1
# 500                1344    239        1
#
# [500 rows x 5 columns]

# %%
# step3 select cluster with the threhold at 50  
dataList = []
for clusterIndex in cluster.Cluster.unique():
    subCluster = cluster[cluster.Cluster.eq(clusterIndex)]
    data = GOAncestor[GOAncestor.GO.isin(subCluster.GO)]
    data_pivot = data.pivot(index='GO', columns='Ancestor', values='GO')
    percent = 100 - (data_pivot.isnull().sum() * 100 / len(data_pivot))
    missing_value_df = pd.DataFrame({'column_name': data_pivot.columns,
                                    'percent': percent})
    data = missing_value_df.nlargest(1, "percent")[["percent"]]
    data["Cluster"] = clusterIndex
    dataList.append(data)
data = reduce(lambda df1,df2: pd.concat([df1, df2]),  dataList).sort_values(by= ["Cluster"])
data["Count"] = cluster.groupby(["Cluster"]).agg("count")["GO"].values
data = data.sort_values(by=["percent"])
selectedCluster = data[data.percent.gt(50)]
selectedCluster
# Out:
#                                         percent  Cluster  Count
# Ancestor
# organic substance metabolic process   54.189944        0    180
# cellular metabolic process           100.000000        2     13

# %%
# step4 find the GOs In the above cluster
listGO = []
for Cluster in selectedCluster.Cluster.unique():
    result =  GOAncestor[GOAncestor.GO.isin(cluster[cluster.Cluster.eq(Cluster)].GO)].drop_duplicates(subset=["Name"])
    result["Cluster"] = Cluster
    # print(selectedCluster[selectedCluster.Cluster.eq(Cluster)].index.values)
    result["Type"] = str(selectedCluster[selectedCluster.Cluster.eq(Cluster)].index[0])
    listGO.append(result)
GOs = reduce(lambda df1,df2: pd.concat([df1, df2]),  listGO).sort_values(by= ["Cluster"])
GOs = GOs.drop(columns=[ "Ancestor", "AncestorGO"])
GOs
# Out:
#                GO                                               Name  Cluster  \
# 4      GO:0000012                         single strand break repair        0
# 12249  GO:0006370                     7-methylguanosine mRNA capping        0
# 12258  GO:0006378                               mRNA polyadenylation        0
# 12266  GO:0006382                       adenosine to inosine editing        0
# 12290  GO:0006388  tRNA splicing, via endonucleolytic cleavage an...        0
# ...           ...                                                ...      ...
# 1180   GO:0000727  double-strand break repair via break-induced r...        2
# 1168   GO:0000724  double-strand break repair via homologous reco...        2
# 1163   GO:0000723                               telomere maintenance        2
# 11893  GO:0006270                         DNA replication initiation        2
# 12603  GO:0006471                           protein ADP-ribosylation        2
#
#                                       Type
# 4      organic substance metabolic process
# 12249  organic substance metabolic process
# 12258  organic substance metabolic process
# 12266  organic substance metabolic process
# 12290  organic substance metabolic process
# ...                                    ...
# 1180            cellular metabolic process
# 1168            cellular metabolic process
# 1163            cellular metabolic process
# 11893           cellular metabolic process
# 12603           cellular metabolic process
#
# [192 rows x 4 columns]

# %%
# step5 calculate the correlation between the GOs
AgeGapPerGOPath = "discovery3KAgeGapPerGOSub.csv"
AgeGapPerGO = pd.read_csv(AgeGapPerGOPath, index_col=0)
AgeGapPerGO = AgeGapPerGO[list(GOs.GO.values)]
heatmap = AgeGapPerGO.corr()
upper_triangle_values =  heatmap.mask(np.triu(np.ones(heatmap.shape)).astype(bool)).fillna(0)
upper_triangle_values
# Out:
#             GO:0000012  GO:0006370  GO:0006378  GO:0006382  GO:0006388  \
# GO:0000012    0.000000    0.000000    0.000000    0.000000    0.000000
# GO:0006370    0.049341    0.000000    0.000000    0.000000    0.000000
# GO:0006378    0.070961    0.003836    0.000000    0.000000    0.000000
# GO:0006382    0.056345    0.019158    0.116190    0.000000    0.000000
# GO:0006388    0.046119    0.002030    0.410208    0.086604    0.000000
# ...                ...         ...         ...         ...         ...
# GO:0000727    0.064204    0.034033    0.099053    0.065347    0.061698
# GO:0000724    0.055913    0.021844    0.200475    0.128937    0.139109
# GO:0000723    0.046963    0.013090    0.188692    0.098206    0.114406
# GO:0006270    0.037398    0.041613    0.115131    0.084389    0.085501
# GO:0006471    0.044347   -0.000499    0.159824    0.078776    0.109908
#
#             GO:0006390  GO:0006398  GO:0006402  GO:0006418  GO:0006367  ...  \
# GO:0000012    0.000000    0.000000    0.000000    0.000000    0.000000  ...
# GO:0006370    0.000000    0.000000    0.000000    0.000000    0.000000  ...
# GO:0006378    0.000000    0.000000    0.000000    0.000000    0.000000  ...
# GO:0006382    0.000000    0.000000    0.000000    0.000000    0.000000  ...
# GO:0006388    0.000000    0.000000    0.000000    0.000000    0.000000  ...
# ...                ...         ...         ...         ...         ...  ...
# GO:0000727    0.038185    0.097048    0.099018    0.018187    0.107491  ...
# GO:0000724    0.151010    0.122891    0.207820    0.061002    0.189756  ...
# GO:0000723    0.127186    0.092199    0.174965    0.084472    0.203067  ...
# GO:0006270    0.067931    0.126112    0.135955    0.043796    0.143153  ...
# GO:0006471    0.099857    0.078945    0.177860    0.056692    0.176111  ...
#
#             GO:0006298  GO:0006284  GO:0006310  GO:0006268  GO:0006260  \
# GO:0000012    0.000000    0.000000    0.000000    0.000000    0.000000
# GO:0006370    0.000000    0.000000    0.000000    0.000000    0.000000
# GO:0006378    0.000000    0.000000    0.000000    0.000000    0.000000
# GO:0006382    0.000000    0.000000    0.000000    0.000000    0.000000
# GO:0006388    0.000000    0.000000    0.000000    0.000000    0.000000
# ...                ...         ...         ...         ...         ...
# GO:0000727    0.100078    0.105788    0.121308    0.447384    0.267345
# GO:0000724    0.482623    0.455134    0.557668    0.473411    0.561821
# GO:0000723    0.468270    0.498767    0.383007    0.370897    0.508402
# GO:0006270    0.124710    0.140626    0.178601    0.491169    0.304174
# GO:0006471    0.185606    0.135760    0.240509    0.171628    0.264617
#
#             GO:0000727  GO:0000724  GO:0000723  GO:0006270  GO:0006471
# GO:0000012    0.000000    0.000000    0.000000    0.000000         0.0
# GO:0006370    0.000000    0.000000    0.000000    0.000000         0.0
# GO:0006378    0.000000    0.000000    0.000000    0.000000         0.0
# GO:0006382    0.000000    0.000000    0.000000    0.000000         0.0
# GO:0006388    0.000000    0.000000    0.000000    0.000000         0.0
# ...                ...         ...         ...         ...         ...
# GO:0000727    0.000000    0.000000    0.000000    0.000000         0.0
# GO:0000724    0.148802    0.000000    0.000000    0.000000         0.0
# GO:0000723    0.112793    0.583297    0.000000    0.000000         0.0
# GO:0006270    0.676463    0.197531    0.150923    0.000000         0.0
# GO:0006471    0.067321    0.224304    0.427894    0.092256         0.0
#
# [192 rows x 192 columns]

# %%
# step6 prepare data for plot
nodes = GOs[["GO", "Cluster"]].rename(columns={"GO": "id", "Cluster": "group"})
print(GOs.Cluster.unique())
nodes = nodes.to_dict(orient='records')
link = []
for index, row in upper_triangle_values.iterrows():
    for column in upper_triangle_values.columns:
        if row[column] < -0.25 or row[column] > 0.25:
            dict = {}
            # print(f"Row {index}, Column {column}: Value is not equal to 1 ({row[column]})")
            dict["source"] = index 
            dict["target"] = column
            dict["value"] =  row[column]
            link.append(dict)
result = {}
result["nodes"] = nodes
result["links"] = link
file_name = "./dataSub.json"
# Out:
# [0 2]

# %%
# step7 plot in D3
# run the code below and open the website http://127.0.0.1:5000
with open(file_name, "w") as json_file:
    json.dump(result, json_file)
app = Flask(__name__)
@app.route('/')
def index():
    return render_template('./index.html')
if __name__ == '__main__':
    app.run()
